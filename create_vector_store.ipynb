# %%
import time
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
from langchain.docstore.document import Document
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
import openai
from langchain.embeddings import AzureOpenAIEmbeddings
import spacy
import warnings
import faiss
import numpy as np
import json
import pandas as pd
import matplotlib.pyplot as plt
from langchain.vectorstores import FAISS
from langchain_community.docstore.in_memory import InMemoryDocstore
import dotenv, os

_ = dotenv.load_dotenv(dotenv.find_dotenv())

embeddings = AzureOpenAIEmbeddings(
    deployment = os.getenv("Embeddings_GPT_4_DEPLOYMENT_NAME"),
    model = os.getenv("Embeddings_GPT_4_MODEL"),
    openai_api_base = os.getenv("Embeddings_GPT_4_API_BASE"),
    openai_api_key = os.getenv("Embeddings_GPT_4_API_KEY"),
    openai_api_version = os.getenv("Embeddings_GPT_4_API_VERSION"),
    openai_api_type = os.getenv("Embeddings_GPT_4_API_TYPE"),
    chunk_size = 1
)

def crawl_website(start_url, max_pages=1000):
    visited = set()
    frontier = [start_url]
    pages = []
    
    while frontier and len(visited) < max_pages:
        url = frontier.pop(0)
        if url in visited:
            continue
        print(f"Crawling: {url}")
        try:
            response = requests.get(url, timeout=10)
        except Exception as e:
            print(f"Error fetching {url}: {e}")
            visited.add(url)
            continue
        
        if response.status_code != 200:
            print(f"Non-200 status code for {url}")
            visited.add(url)
            continue
        
        content_type = response.headers.get("Content-Type", "")
        if "text/html" not in content_type:
            visited.add(url)
            continue
        
        soup = BeautifulSoup(response.text, "html.parser")
        text = soup.get_text(separator="\n")
        pages.append({"url": url, "content": text})
        visited.add(url)
        
        # Extract all links and add those within the aptos.dev domain
        for link in soup.find_all("a", href=True):
            href = link.get("href")
            full_url = urljoin(url, href)
            parsed = urlparse(full_url)
            # Only follow links that belong to the aptos.dev domain
            if "aptos.dev" in parsed.netloc:
                # Remove any URL fragment for consistency
                full_url = full_url.split("#")[0]
                if full_url not in visited and full_url not in frontier:
                    frontier.append(full_url)
        
        # Be polite and wait a short period between requests
        time.sleep(0.5)
                    
    return pages

# Starting URL for the Aptos documentation
start_url = "https://aptos.dev/en/build/get-started"
pages = crawl_website(start_url, max_pages=1000)
print(f"Total pages scraped: {len(pages)}")

# Convert scraped pages to LangChain Document objects with metadata.
documents = [
    Document(page_content=page["content"], metadata={"source": page["url"]})
    for page in pages
]

index = faiss.IndexFlatIP(len(embeddings.embed_query("Hello World")))
index.reset()

vectorstore = FAISS( 
    embedding_function=embeddings, 
    index = index,
    docstore=InMemoryDocstore({}),
    index_to_docstore_id = {}
)

# Split documents into smaller chunks to improve the quality of vector embeddings.
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
split_docs = text_splitter.split_documents(documents)

# Initialize embeddings using a HuggingFace model and build a FAISS vector store.

vectorstore.add_texts(split_docs)

print("Vectorstore created.")
print("Number of vectors:", len(vectorstore.index_to_docstore_id))
# Out:
# Crawling: https://aptos.dev/en/build/get-started
# Crawling: https://aptos.dev/
# Crawling: https://aptos.dev/en/build/get-started/developer-setup
# Crawling: https://aptos.dev/en/build/get-started/ethereum-cheatsheet
# Crawling: https://aptos.dev/en/build/get-started/solana-cheatsheet
# Crawling: https://aptos.dev/en/build/smart-contracts
# Crawling: https://aptos.dev/en/build/smart-contracts/why-move
# Crawling: https://aptos.dev/en/build/smart-contracts/create-package
# Crawling: https://aptos.dev/en/build/smart-contracts/compiling
# Crawling: https://aptos.dev/en/build/smart-contracts/book/unit-testing
# Crawling: https://aptos.dev/en/build/smart-contracts/deployment
# Crawling: https://aptos.dev/en/build/smart-contracts/debugging
# Crawling: https://aptos.dev/en/build/smart-contracts/bcs
# Crawling: https://aptos.dev/en/build/smart-contracts/object/creating-objects
# Crawling: https://aptos.dev/en/build/smart-contracts/object/using-objects
# Crawling: https://aptos.dev/en/build/smart-contracts/digital-asset
# Crawling: https://aptos.dev/en/build/smart-contracts/fungible-asset
# Crawling: https://aptos.dev/en/build/smart-contracts/aptos-coin
# Crawling: https://aptos.dev/en/build/smart-contracts/aptos-token
# Crawling: https://aptos.dev/en/network/blockchain/accounts
# Crawling: https://aptos.dev/en/build/smart-contracts/table
# Crawling: https://aptos.dev/en/build/smart-contracts/objects
# Crawling: https://aptos.dev/en/build/smart-contracts/resource-accounts
# Crawling: https://aptos.dev/en/build/smart-contracts/book/structs-and-resources
# Crawling: https://aptos.dev/en/build/smart-contracts/vector
# Crawling: https://aptos.dev/en/build/smart-contracts/smart-vector
# Crawling: https://aptos.dev/en/build/smart-contracts/smart-table
# Crawling: https://aptos.dev/en/build/smart-contracts/reference
# Crawling: https://aptos.dev/en/build/smart-contracts/book
# Crawling: https://aptos.dev/en/build/smart-contracts/book/SUMMARY
# Crawling: https://aptos.dev/en/build/smart-contracts/book/move-2
# Crawling: https://aptos.dev/en/build/smart-contracts/book/modules-and-scripts
# Crawling: https://aptos.dev/en/build/smart-contracts/book/move-tutorial
# Crawling: https://aptos.dev/en/build/smart-contracts/book/integers
# Crawling: https://aptos.dev/en/build/smart-contracts/book/bool
# Crawling: https://aptos.dev/en/build/smart-contracts/book/address
# Crawling: https://aptos.dev/en/build/smart-contracts/book/vector
# Crawling: https://aptos.dev/en/build/smart-contracts/book/signer
# Crawling: https://aptos.dev/en/build/smart-contracts/book/references
# Crawling: https://aptos.dev/en/build/smart-contracts/book/tuples
# Crawling: https://aptos.dev/en/build/smart-contracts/book/variables
# Crawling: https://aptos.dev/en/build/smart-contracts/book/equality
# Crawling: https://aptos.dev/en/build/smart-contracts/book/abort-and-assert
# Crawling: https://aptos.dev/en/build/smart-contracts/book/conditionals
# Crawling: https://aptos.dev/en/build/smart-contracts/book/loops
# Crawling: https://aptos.dev/en/build/smart-contracts/book/functions
# Crawling: https://aptos.dev/en/build/smart-contracts/book/enums
# Crawling: https://aptos.dev/en/build/smart-contracts/book/constants
# Crawling: https://aptos.dev/en/build/smart-contracts/book/generics
# Crawling: https://aptos.dev/en/build/smart-contracts/book/abilities
# Crawling: https://aptos.dev/en/build/smart-contracts/book/uses
# Crawling: https://aptos.dev/en/build/smart-contracts/book/friends
# Crawling: https://aptos.dev/en/build/smart-contracts/book/packages
# Crawling: https://aptos.dev/en/build/smart-contracts/book/package-upgrades
# Crawling: https://aptos.dev/en/build/smart-contracts/book/global-storage-structure
# Crawling: https://aptos.dev/en/build/smart-contracts/book/global-storage-operators
# Crawling: https://aptos.dev/en/build/smart-contracts/book/standard-library
# Crawling: https://aptos.dev/en/build/smart-contracts/book/coding-conventions
# Crawling: https://aptos.dev/en/build/smart-contracts/error-codes
# Crawling: https://aptos.dev/en/build/smart-contracts/scripts
# Crawling: https://aptos.dev/en/build/smart-contracts/scripts/writing-scripts
# Crawling: https://aptos.dev/en/build/smart-contracts/scripts/compiling-scripts
# Crawling: https://aptos.dev/en/build/smart-contracts/scripts/running-scripts
# Crawling: https://aptos.dev/en/build/smart-contracts/scripts/script-tutorial
# Crawling: https://aptos.dev/en/build/smart-contracts/prover
# Crawling: https://aptos.dev/en/build/smart-contracts/prover/prover-guide
# Crawling: https://aptos.dev/en/build/smart-contracts/prover/supporting-resources
# Crawling: https://aptos.dev/en/build/smart-contracts/prover/spec-lang
# Crawling: https://aptos.dev/en/build/smart-contracts/randomness
# Crawling: https://aptos.dev/en/build/smart-contracts/cryptography
# Crawling: https://aptos.dev/en/build/smart-contracts/move-security-guidelines
# Crawling: https://aptos.dev/en/build/cli/working-with-move-contracts/local-simulation-benchmarking-and-gas-profiling
# Crawling: https://aptos.dev/en/build/smart-contracts/compiler_v2
# Crawling: https://aptos.dev/en/build/smart-contracts/linter
# Crawling: https://aptos.dev/en/build/smart-contracts/aptos-standards
# Crawling: https://aptos.dev/en/build/smart-contracts/modules-on-aptos
# Crawling: https://aptos.dev/en/build/smart-contracts/move-reference
# Crawling: https://aptos.dev/en/build/smart-contracts/third-party-dependencies
# Crawling: https://aptos.dev/en/build/smart-contracts/tokens
# Crawling: https://aptos.dev/en/build/apis
# Crawling: https://aptos.dev/en/build/apis/fullnode-rest-api-reference
# Crawling: https://aptos.dev/en/build/apis/fullnode-rest-api
# Crawling: https://aptos.dev/en/build/indexer
# Crawling: https://aptos.dev/en/build/apis/data-providers
# Crawling: https://aptos.dev/en/build/apis/faucet-api
# Crawling: https://aptos.dev/en/build/apis/aptos-labs-developer-portal
# Crawling: https://aptos.dev/en/build/sdks
# Crawling: https://aptos.dev/en/build/sdks/ts-sdk
# Crawling: https://aptos.dev/en/build/sdks/ts-sdk/quickstart
# Crawling: https://aptos.dev/en/build/sdks/ts-sdk/account
# Crawling: https://aptos.dev/en/build/sdks/ts-sdk/account/account-abstraction
# Crawling: https://aptos.dev/en/build/sdks/ts-sdk/fetch-data-via-sdk
# Crawling: https://aptos.dev/en/build/sdks/ts-sdk/building-transactions
# Crawling: https://aptos.dev/en/build/sdks/ts-sdk/building-transactions/simulating-transactions
# Crawling: https://aptos.dev/en/build/sdks/ts-sdk/building-transactions/multi-agent-transactions
# Crawling: https://aptos.dev/en/build/sdks/ts-sdk/building-transactions/sponsoring-transactions
# Crawling: https://aptos.dev/en/build/sdks/ts-sdk/building-transactions/batching-transactions
# Crawling: https://aptos.dev/en/build/sdks/ts-sdk/building-transactions/bcs-format
# Crawling: https://aptos.dev/en/build/sdks/ts-sdk/building-transactions/script-composer
# Crawling: https://aptos.dev/en/build/sdks/ts-sdk/ts-examples
# Crawling: https://aptos.dev/en/build/sdks/ts-sdk/type-safe-contract
# Crawling: https://aptos.dev/en/build/sdks/ts-sdk/legacy-ts-sdk
# Crawling: https://aptos.dev/en/build/sdks/ts-sdk/legacy-ts-sdk/migration-guide
# Crawling: https://aptos.dev/en/build/sdks/python-sdk
# Crawling: https://aptos.dev/en/build/sdks/go-sdk
# Crawling: https://aptos.dev/en/build/sdks/go-sdk/account
# Crawling: https://aptos.dev/en/build/sdks/go-sdk/fetch-data-via-sdk
# Crawling: https://aptos.dev/en/build/sdks/go-sdk/building-transactions
# Crawling: https://aptos.dev/en/build/sdks/go-sdk/building-transactions/simulating-transactions
# Crawling: https://aptos.dev/en/build/sdks/go-sdk/building-transactions/multi-agent-transactions
# Crawling: https://aptos.dev/en/build/sdks/go-sdk/building-transactions/sponsoring-transactions
# Crawling: https://aptos.dev/en/build/sdks/go-sdk/building-transactions/batching-transactions
# Crawling: https://aptos.dev/en/build/sdks/go-sdk/building-transactions/bcs-format
# Crawling: https://aptos.dev/en/build/sdks/go-sdk/go-examples
# Crawling: https://aptos.dev/en/build/sdks/rust-sdk
# Crawling: https://aptos.dev/en/build/sdks/dotnet-sdk
# Crawling: https://aptos.dev/en/build/sdks/dotnet-sdk/getting-started
# Crawling: https://aptos.dev/en/build/sdks/dotnet-sdk/unity-integration
# Crawling: https://aptos.dev/en/build/sdks/dotnet-sdk/godot-integration
# Crawling: https://aptos.dev/en/build/sdks/dotnet-sdk/accounts/ed25519
# Crawling: https://aptos.dev/en/build/sdks/dotnet-sdk/accounts/keyless
# Crawling: https://aptos.dev/en/build/sdks/dotnet-sdk/accounts/multikey
# Crawling: https://aptos.dev/en/build/sdks/dotnet-sdk/transactions/basic-transactions
# Crawling: https://aptos.dev/en/build/sdks/dotnet-sdk/transactions/sponsored-transactions
# Crawling: https://aptos.dev/en/build/sdks/dotnet-sdk/queries/view
# Crawling: https://aptos.dev/en/build/sdks/dotnet-sdk/dotnet-examples
# Crawling: https://aptos.dev/en/build/sdks/cpp-sdk
# Crawling: https://aptos.dev/en/build/sdks/unity-sdk
# Crawling: https://aptos.dev/en/build/sdks/wallet-adapter
# Crawling: https://aptos.dev/en/build/sdks/wallet-adapter/dapp
# Crawling: https://aptos.dev/en/build/sdks/wallet-adapter/browser-extension-wallets
# Crawling: https://aptos.dev/en/build/sdks/wallet-adapter/wallets
# Crawling: https://aptos.dev/en/build/sdks/wallet-adapter/wallet-standards
# Crawling: https://aptos.dev/en/build/sdks/community-sdks
# Crawling: https://aptos.dev/en/build/sdks/community-sdks/kotlin-sdk
# Crawling: https://aptos.dev/en/build/sdks/community-sdks/kotlin-sdk/quickstart
# Crawling: https://aptos.dev/en/build/sdks/community-sdks/kotlin-sdk/account
# Crawling: https://aptos.dev/en/build/sdks/community-sdks/kotlin-sdk/fetch-data-via-sdk
# Crawling: https://aptos.dev/en/build/sdks/community-sdks/kotlin-sdk/building-transactions
# Crawling: https://aptos.dev/en/build/sdks/community-sdks/kotlin-sdk/sponsored-transactions
# Crawling: https://aptos.dev/en/build/sdks/community-sdks/kotlin-sdk/for-ios-devs/aptos-kit
# Crawling: https://aptos.dev/en/build/sdks/community-sdks/kotlin-sdk/for-ios-devs/getting-started
# Crawling: https://aptos.dev/en/build/sdks/community-sdks/kotlin-sdk/client-configuration
# Crawling: https://aptos.dev/en/build/sdks/community-sdks/swift-sdk
# Crawling: https://aptos.dev/en/build/sdks/community-sdks/unity-opendive-sdk
# Crawling: https://aptos.dev/en/build/indexer/indexer-api
# Crawling: https://aptos.dev/en/build/indexer/indexer-api/indexer-reference
# Crawling: https://aptos.dev/en/build/indexer/indexer-api/architecture
# Crawling: https://aptos.dev/en/build/indexer/indexer-api/self-hosted
# Error fetching https://aptos.dev/en/build/indexer/indexer-api/self-hosted: HTTPSConnectionPool(host='aptos.dev', port=443): Max retries exceeded with url: /en/build/indexer/indexer-api/self-hosted (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x7a6af42dfd90>, 'Connection to aptos.dev timed out. (connect timeout=10)'))
# Crawling: https://aptos.dev/en/build/indexer/indexer-api/fungible-asset-balances
# Crawling: https://aptos.dev/en/build/indexer/indexer-api/account-transactions
# Crawling: https://aptos.dev/en/build/indexer/indexer-api/ans-lookup
# Crawling: https://aptos.dev/en/build/indexer/indexer-api/fungible-asset-info
# Crawling: https://aptos.dev/en/build/indexer/indexer-api/get-nft-collections
# Crawling: https://aptos.dev/en/build/indexer/indexer-api/get-nfts
# Crawling: https://aptos.dev/en/build/indexer/indexer-api/token-metadata
# Crawling: https://aptos.dev/en/build/indexer/indexer-api/get-delegators
# Crawling: https://aptos.dev/en/build/indexer/indexer-sdk
# Crawling: https://aptos.dev/en/build/indexer/indexer-sdk/quickstart
# Crawling: https://aptos.dev/en/build/indexer/indexer-sdk/documentation
# Crawling: https://aptos.dev/en/build/indexer/indexer-sdk/documentation/setup
# Crawling: https://aptos.dev/en/build/indexer/indexer-sdk/documentation/define-schema
# Crawling: https://aptos.dev/en/build/indexer/indexer-sdk/documentation/create-processor
# Crawling: https://aptos.dev/en/build/indexer/indexer-sdk/documentation/steps
# Crawling: https://aptos.dev/en/build/indexer/indexer-sdk/documentation/steps/transaction-stream
# Crawling: https://aptos.dev/en/build/indexer/indexer-sdk/documentation/steps/parsing-txns
# Crawling: https://aptos.dev/en/build/indexer/indexer-sdk/documentation/connect-steps
# Crawling: https://aptos.dev/en/build/indexer/indexer-sdk/documentation/version-tracking
# Crawling: https://aptos.dev/en/build/indexer/indexer-sdk/documentation/run-processor
# Crawling: https://aptos.dev/en/build/indexer/indexer-sdk/documentation/advanced-tutorials
# Crawling: https://aptos.dev/en/build/indexer/indexer-sdk/advanced-tutorials/migration-guide
# Crawling: https://aptos.dev/en/build/indexer/indexer-sdk/advanced-tutorials/txn-importer
# Crawling: https://aptos.dev/en/build/indexer/txn-stream
# Crawling: https://aptos.dev/en/build/indexer/txn-stream/aptos-hosted-txn-stream
# Crawling: https://aptos.dev/en/build/indexer/txn-stream/self-hosted
# Crawling: https://aptos.dev/en/build/indexer/txn-stream/local-development
# Crawling: https://aptos.dev/en/build/indexer/legacy
# Crawling: https://aptos.dev/en/build/indexer/legacy/indexer-fullnode
# Crawling: https://aptos.dev/en/build/indexer/legacy/custom-data-model
# Crawling: https://aptos.dev/en/build/indexer/legacy/migration
# Crawling: https://aptos.dev/en/build/cli
# Crawling: https://aptos.dev/en/build/cli/install-cli/install-cli-mac
# Crawling: https://aptos.dev/en/build/cli/install-cli/install-cli-windows
# Crawling: https://aptos.dev/en/build/cli/install-cli/install-cli-linux
# Crawling: https://aptos.dev/en/build/cli/install-cli/install-cli-specific-version
# Crawling: https://aptos.dev/en/build/cli/setup-cli
# Crawling: https://aptos.dev/en/build/cli/setup-cli/install-move-prover
# Crawling: https://aptos.dev/en/build/cli/start-from-template
# Crawling: https://aptos.dev/en/build/cli/working-with-move-contracts
# Crawling: https://aptos.dev/en/build/cli/working-with-move-contracts/arguments-in-json-tutorial
# Crawling: https://aptos.dev/en/build/cli/working-with-move-contracts/multi-signature-tutorial
# Crawling: https://aptos.dev/en/build/cli/formatting-move-contracts
# Crawling: https://aptos.dev/en/build/cli/trying-things-on-chain
# Crawling: https://aptos.dev/en/build/cli/trying-things-on-chain/looking-up-account-info
# Crawling: https://aptos.dev/en/build/cli/trying-things-on-chain/create-test-accounts
# Crawling: https://aptos.dev/en/build/cli/trying-things-on-chain/ledger
# Crawling: https://aptos.dev/en/build/cli/replay-past-transactions
# Crawling: https://aptos.dev/en/build/cli/running-a-local-network
# Crawling: https://aptos.dev/en/build/cli/managing-a-network-node
# Crawling: https://aptos.dev/en/build/cli/public-network
# Crawling: https://aptos.dev/en/build/create-aptos-dapp
# Crawling: https://aptos.dev/en/build/create-aptos-dapp/faq
# Crawling: https://aptos.dev/en/build/guides
# Crawling: https://aptos.dev/en/build/guides/first-transaction
# Crawling: https://aptos.dev/en/build/guides/build-e2e-dapp
# Crawling: https://aptos.dev/en/build/guides/build-e2e-dapp/1-create-smart-contract
# Crawling: https://aptos.dev/en/build/guides/build-e2e-dapp/2-set-up-react-app
# Crawling: https://aptos.dev/en/build/guides/build-e2e-dapp/3-add-wallet-support
# Crawling: https://aptos.dev/en/build/guides/build-e2e-dapp/4-fetch-data-from-chain
# Crawling: https://aptos.dev/en/build/guides/build-e2e-dapp/5-submit-data-to-chain
# Crawling: https://aptos.dev/en/build/guides/build-e2e-dapp/6-handle-tasks
# Crawling: https://aptos.dev/en/build/guides/your-first-nft
# Crawling: https://aptos.dev/en/build/guides/first-coin
# Crawling: https://aptos.dev/en/build/guides/first-fungible-asset
# Crawling: https://aptos.dev/en/build/guides/first-move-module
# Crawling: https://aptos.dev/en/build/guides/first-multisig
# Crawling: https://aptos.dev/en/build/guides/multisig-managed-fungible-asset
# Crawling: https://aptos.dev/en/build/guides/aptos-keyless
# Crawling: https://aptos.dev/en/build/guides/aptos-keyless/introduction
# Crawling: https://aptos.dev/en/build/guides/aptos-keyless/oidc-support
# Crawling: https://aptos.dev/en/build/guides/aptos-keyless/integration-guide
# Crawling: https://aptos.dev/en/build/guides/aptos-keyless/simple-example
# Crawling: https://aptos.dev/en/build/guides/aptos-keyless/how-keyless-works
# Crawling: https://aptos.dev/en/build/guides/aptos-keyless/other
# Crawling: https://aptos.dev/en/build/guides/aptos-keyless/federated-keyless
# Crawling: https://aptos.dev/en/build/guides/aptos-keyless/federated-keyless/key-considerations
# Crawling: https://aptos.dev/en/build/guides/aptos-keyless/federated-keyless/integration-guide
# Crawling: https://aptos.dev/en/build/guides/aptos-keyless/federated-keyless/other
# Crawling: https://aptos.dev/en/build/guides/sponsored-transactions
# Crawling: https://aptos.dev/en/build/guides/transaction-management
# Crawling: https://aptos.dev/en/build/guides/key-rotation
# Crawling: https://aptos.dev/en/build/guides/exchanges
# Crawling: https://aptos.dev/en/build/guides/system-integrators-guide
# Crawling: https://aptos.dev/en/build/guides/oracles
# Crawling: https://aptos.dev/en/network/blockchain/blockchain-deep-dive
# Crawling: https://aptos.dev/en/network/blockchain/move
# Crawling: https://aptos.dev/en/network/nodes/full-node
# Crawling: https://aptos.dev/en/network/nodes/validator-node
# Crawling: https://aptos.dev/en/network/blockchain/execution
# Crawling: https://aptos.dev/en/network/blockchain/validator-nodes
# Crawling: https://aptos.dev/en/network/blockchain/gas-txn-fee
# Crawling: https://aptos.dev/en/network/blockchain/node-networks-sync
# Crawling: https://aptos.dev/en/network/nodes/configure/state-sync
# Crawling: https://aptos.dev/en/network/blockchain/governance
# Crawling: https://aptos.dev/en/network/nodes
# Crawling: https://aptos.dev/en/network/blockchain/aptos-white-paper
# Crawling: https://aptos.dev/reference/move?branch=mainnet&page=aptos-framework/doc/object.md
# Crawling: https://aptos.dev/reference/move/?branch=mainnet&page=aptos-token-objects/doc/royalty.md
# Crawling: https://aptos.dev/reference/move/?branch=mainnet&page=aptos-framework/doc/object.md
# Crawling: https://aptos.dev/reference/move/?branch=mainnet&page=aptos-token-objects/doc/aptos_token.md
# Crawling: https://aptos.dev/reference/move/?branch=mainnet&page=aptos-framework/doc/fungible_asset.md
# Crawling: https://aptos.dev/docs/aptos-token-standard-flow.svg
# Crawling: https://aptos.dev/en/network/blockchain
# Crawling: https://aptos.dev/en/network/blockchain/events
# Crawling: https://aptos.dev/en/network/blockchain/fullnodes
# Crawling: https://aptos.dev/en/network/blockchain/resources
# Crawling: https://aptos.dev/en/network/blockchain/txns-states
# Crawling: https://aptos.dev/en/network/blockchain/base-gas
# Crawling: https://aptos.dev/en/network/blockchain/blocks
# Crawling: https://aptos.dev/en/network/blockchain/staking
# Crawling: https://aptos.dev/en/network/blockchain/delegated-staking
# Crawling: https://aptos.dev/en/network/nodes/localnet
# Crawling: https://aptos.dev/en/network/nodes/localnet/local-development-network
# Crawling: https://aptos.dev/en/network/nodes/localnet/run-a-localnet
# Crawling: https://aptos.dev/en/network/nodes/validator-node/operator
# Crawling: https://aptos.dev/en/network/nodes/validator-node/node-requirements
# Crawling: https://aptos.dev/en/network/nodes/validator-node/deploy-nodes
# Crawling: https://aptos.dev/en/network/nodes/validator-node/deploy-nodes/using-source-code
# Crawling: https://aptos.dev/en/network/nodes/validator-node/deploy-nodes/using-docker
# Crawling: https://aptos.dev/en/network/nodes/validator-node/deploy-nodes/using-aws
# Crawling: https://aptos.dev/en/network/nodes/validator-node/deploy-nodes/using-azure
# Crawling: https://aptos.dev/en/network/nodes/validator-node/deploy-nodes/using-gcp
# Crawling: https://aptos.dev/en/network/nodes/validator-node/connect-nodes
# Crawling: https://aptos.dev/en/network/nodes/validator-node/connect-nodes/connect-to-aptos-network
# Crawling: https://aptos.dev/en/network/nodes/validator-node/connect-nodes/staking-pool-operations
# Crawling: https://aptos.dev/en/network/nodes/validator-node/connect-nodes/delegation-pool-operations
# Crawling: https://aptos.dev/en/network/nodes/validator-node/connect-nodes/staking-pool-voter
# Crawling: https://aptos.dev/en/network/nodes/validator-node/verify-nodes
# Crawling: https://aptos.dev/en/network/nodes/validator-node/verify-nodes/node-liveness-criteria
# Crawling: https://aptos.dev/en/network/nodes/validator-node/verify-nodes/leaderboard-metrics
# Crawling: https://aptos.dev/en/network/nodes/validator-node/modify-nodes
# Crawling: https://aptos.dev/en/network/nodes/validator-node/modify-nodes/update-validator-node
# Crawling: https://aptos.dev/en/network/nodes/validator-node/modify-nodes/shutting-down-nodes
# Crawling: https://aptos.dev/en/network/nodes/validator-node/modify-nodes/rotate-consensus-key
# Crawling: https://aptos.dev/en/network/nodes/full-node/pfn-requirements
# Crawling: https://aptos.dev/en/network/nodes/full-node/deployments
# Crawling: https://aptos.dev/en/network/nodes/full-node/deployments/using-source-code
# Crawling: https://aptos.dev/en/network/nodes/full-node/deployments/using-docker
# Crawling: https://aptos.dev/en/network/nodes/full-node/deployments/using-gcp
# Crawling: https://aptos.dev/en/network/nodes/full-node/verify-pfn
# Crawling: https://aptos.dev/en/network/nodes/full-node/modify
# Crawling: https://aptos.dev/en/network/nodes/full-node/modify/fullnode-network-connections
# Crawling: https://aptos.dev/en/network/nodes/full-node/modify/network-identity-fullnode
# Crawling: https://aptos.dev/en/network/nodes/full-node/modify/update-fullnode-with-new-releases
# Crawling: https://aptos.dev/en/network/nodes/bootstrap-fullnode
# Crawling: https://aptos.dev/en/network/nodes/bootstrap-fullnode/aptos-db-restore
# Crawling: https://aptos.dev/en/network/nodes/bootstrap-fullnode/bootstrap-fullnode
# Crawling: https://aptos.dev/en/network/nodes/configure
# Crawling: https://aptos.dev/en/network/nodes/configure/consensus-observer
# Crawling: https://aptos.dev/en/network/nodes/configure/data-pruning
# Crawling: https://aptos.dev/en/network/nodes/configure/telemetry
# Crawling: https://aptos.dev/en/network/nodes/configure/node-files-all-networks
# Crawling: https://aptos.dev/en/network/nodes/configure/node-files-all-networks/node-files-mainnet
# Crawling: https://aptos.dev/en/network/nodes/configure/node-files-all-networks/node-files-testnet
# Crawling: https://aptos.dev/en/network/nodes/configure/node-files-all-networks/node-files-devnet
# Crawling: https://aptos.dev/en/network/nodes/measure
# Crawling: https://aptos.dev/en/network/nodes/measure/important-metrics
# Crawling: https://aptos.dev/en/network/nodes/measure/node-health-checker
# Crawling: https://aptos.dev/en/network/nodes/measure/node-health-checker-faq
# Crawling: https://aptos.dev/en/network/nodes/measure/node-inspection-service
# Crawling: https://aptos.dev/en/network/nodes/building-from-source
# Crawling: https://aptos.dev/en/network/nodes/networks
# Crawling: https://aptos.dev/en/network/releases
# Crawling: https://aptos.dev/en/network/glossary
# Crawling: https://aptos.dev/en/network/faucet
# Crawling: https://aptos.dev/guides/randomness/
# Crawling: https://aptos.dev/gas-profiling/sample-report/index.html
# Crawling: https://aptos.dev/en/build/apis/fullnode-rest-api-reference?network=mainnet
# Crawling: https://aptos.dev/en/build/apis/fullnode-rest-api-reference?network=testnet
# Crawling: https://aptos.dev/en/build/apis/fullnode-rest-api-reference?network=devnet
# Crawling: https://aptos.dev/network/faucet
# Crawling: https://aptos.dev/en/build/sdks/sdks/wallet-adapter
# Crawling: https://aptos.dev/en/build/sdks/unity-official-sdk
# Non-200 status code for https://aptos.dev/en/build/sdks/unity-official-sdk
# Crawling: https://aptos.dev/en/build/indexer/indexer-reference
# Non-200 status code for https://aptos.dev/en/build/indexer/indexer-reference
# Crawling: https://aptos.dev/en/build/indexer/custom-processors
# Non-200 status code for https://aptos.dev/en/build/indexer/custom-processors
# Crawling: https://aptos.dev/gas-profiling/sample-report-2/index.html
# Crawling: https://aptos.dev/en/network/nodes/aptos-api-spec
# Crawling: https://aptos.dev/en/build/smart-contracts/move-reference?branch=mainnet&page=aptos-framework%2Fdoc%2Ffungible_asset.md
# Crawling: https://aptos.dev/en/build/smart-contracts/move-reference?page=aptos-framework%2Fdoc%2Fjwks.md
# Crawling: https://aptos.dev/en/build/fetch-price-updates
# Created a chunk of size 5195, which is longer than the specified 1000
# Created a chunk of size 4880, which is longer than the specified 1000
# Created a chunk of size 5128, which is longer than the specified 1000
# Created a chunk of size 5017, which is longer than the specified 1000
# Created a chunk of size 5111, which is longer than the specified 1000
# Created a chunk of size 5039, which is longer than the specified 1000
# Created a chunk of size 5073, which is longer than the specified 1000
# Created a chunk of size 5061, which is longer than the specified 1000
# Created a chunk of size 5211, which is longer than the specified 1000
# Created a chunk of size 5117, which is longer than the specified 1000
# Created a chunk of size 1188, which is longer than the specified 1000
# Created a chunk of size 5132, which is longer than the specified 1000
# Created a chunk of size 5441, which is longer than the specified 1000
# Created a chunk of size 5309, which is longer than the specified 1000
# Created a chunk of size 5223, which is longer than the specified 1000
# Created a chunk of size 5415, which is longer than the specified 1000
# Created a chunk of size 5449, which is longer than the specified 1000
# Created a chunk of size 5341, which is longer than the specified 1000
# Created a chunk of size 5504, which is longer than the specified 1000
# Created a chunk of size 1138, which is longer than the specified 1000
# Created a chunk of size 1837, which is longer than the specified 1000
# Created a chunk of size 5239, which is longer than the specified 1000
# Created a chunk of size 5047, which is longer than the specified 1000
# Created a chunk of size 5033, which is longer than the specified 1000
# Created a chunk of size 5343, which is longer than the specified 1000
# Created a chunk of size 5234, which is longer than the specified 1000
# Created a chunk of size 5282, which is longer than the specified 1000
# Created a chunk of size 5311, which is longer than the specified 1000
# Created a chunk of size 4878, which is longer than the specified 1000
# Created a chunk of size 5044, which is longer than the specified 1000
# Created a chunk of size 5133, which is longer than the specified 1000
# Created a chunk of size 5051, which is longer than the specified 1000
# Created a chunk of size 5053, which is longer than the specified 1000
# Created a chunk of size 4999, which is longer than the specified 1000
# Created a chunk of size 5095, which is longer than the specified 1000
# Created a chunk of size 5036, which is longer than the specified 1000
# Created a chunk of size 5082, which is longer than the specified 1000
# Created a chunk of size 5199, which is longer than the specified 1000
# Created a chunk of size 3444, which is longer than the specified 1000
# Created a chunk of size 5042, which is longer than the specified 1000
# Created a chunk of size 5128, which is longer than the specified 1000
# Created a chunk of size 5081, which is longer than the specified 1000
# Created a chunk of size 5474, which is longer than the specified 1000
# Created a chunk of size 5070, which is longer than the specified 1000
# Created a chunk of size 5080, which is longer than the specified 1000
# Created a chunk of size 5034, which is longer than the specified 1000
# Created a chunk of size 5237, which is longer than the specified 1000
# Created a chunk of size 5407, which is longer than the specified 1000
# Created a chunk of size 5247, which is longer than the specified 1000
# Created a chunk of size 5075, which is longer than the specified 1000
# Created a chunk of size 5418, which is longer than the specified 1000
# Created a chunk of size 5225, which is longer than the specified 1000
# Created a chunk of size 5120, which is longer than the specified 1000
# Created a chunk of size 5038, which is longer than the specified 1000
# Created a chunk of size 5270, which is longer than the specified 1000
# Created a chunk of size 5148, which is longer than the specified 1000
# Created a chunk of size 5036, which is longer than the specified 1000
# Created a chunk of size 5241, which is longer than the specified 1000
# Created a chunk of size 4994, which is longer than the specified 1000
# Created a chunk of size 5089, which is longer than the specified 1000
# Created a chunk of size 5224, which is longer than the specified 1000
# Created a chunk of size 7554, which is longer than the specified 1000
# Created a chunk of size 1846, which is longer than the specified 1000
# Created a chunk of size 1399, which is longer than the specified 1000
# Created a chunk of size 5005, which is longer than the specified 1000
# Created a chunk of size 5078, which is longer than the specified 1000
# Created a chunk of size 5033, which is longer than the specified 1000
# Created a chunk of size 5153, which is longer than the specified 1000
# Created a chunk of size 5061, which is longer than the specified 1000
# Created a chunk of size 4980, which is longer than the specified 1000
# Created a chunk of size 5206, which is longer than the specified 1000
# Created a chunk of size 5156, which is longer than the specified 1000
# Created a chunk of size 5992, which is longer than the specified 1000
# Created a chunk of size 1229, which is longer than the specified 1000
# Created a chunk of size 5495, which is longer than the specified 1000
# Created a chunk of size 5304, which is longer than the specified 1000
# Created a chunk of size 6106, which is longer than the specified 1000
# Created a chunk of size 5295, which is longer than the specified 1000
# Non-200 status code for https://aptos.dev/en/build/fetch-price-updates
# Total pages scraped: 324
# Created a chunk of size 5117, which is longer than the specified 1000
# Created a chunk of size 5319, which is longer than the specified 1000
# Created a chunk of size 5131, which is longer than the specified 1000
# Created a chunk of size 4998, which is longer than the specified 1000
# Created a chunk of size 4992, which is longer than the specified 1000
# Created a chunk of size 5130, which is longer than the specified 1000
# Created a chunk of size 5138, which is longer than the specified 1000
# Created a chunk of size 5052, which is longer than the specified 1000
# Created a chunk of size 5135, which is longer than the specified 1000
# Created a chunk of size 5065, which is longer than the specified 1000
# Created a chunk of size 5164, which is longer than the specified 1000
# Created a chunk of size 5183, which is longer than the specified 1000
# Created a chunk of size 4987, which is longer than the specified 1000
# Created a chunk of size 4985, which is longer than the specified 1000
# Created a chunk of size 5029, which is longer than the specified 1000
# Created a chunk of size 5331, which is longer than the specified 1000
# Created a chunk of size 1400, which is longer than the specified 1000
# Created a chunk of size 5135, which is longer than the specified 1000
# Created a chunk of size 5722, which is longer than the specified 1000
# Created a chunk of size 5097, which is longer than the specified 1000
# Created a chunk of size 5141, which is longer than the specified 1000
# Created a chunk of size 5089, which is longer than the specified 1000
# Created a chunk of size 5450, which is longer than the specified 1000
# Created a chunk of size 5388, which is longer than the specified 1000
# Created a chunk of size 5104, which is longer than the specified 1000
# Created a chunk of size 5023, which is longer than the specified 1000
# Created a chunk of size 5093, which is longer than the specified 1000
# Created a chunk of size 5297, which is longer than the specified 1000
# Created a chunk of size 5161, which is longer than the specified 1000
# Created a chunk of size 5023, which is longer than the specified 1000
# Created a chunk of size 5328, which is longer than the specified 1000
# Created a chunk of size 5085, which is longer than the specified 1000
# Created a chunk of size 4997, which is longer than the specified 1000
# Created a chunk of size 5097, which is longer than the specified 1000
# Created a chunk of size 5060, which is longer than the specified 1000
# Created a chunk of size 5134, which is longer than the specified 1000
# Created a chunk of size 5030, which is longer than the specified 1000
# Created a chunk of size 5460, which is longer than the specified 1000
# Created a chunk of size 5314, which is longer than the specified 1000
# Created a chunk of size 5053, which is longer than the specified 1000
# Created a chunk of size 5057, which is longer than the specified 1000
# Created a chunk of size 5187, which is longer than the specified 1000
# Created a chunk of size 4997, which is longer than the specified 1000
# Created a chunk of size 5118, which is longer than the specified 1000
# Created a chunk of size 5203, which is longer than the specified 1000
# Created a chunk of size 5236, which is longer than the specified 1000
# Created a chunk of size 5172, which is longer than the specified 1000
# Created a chunk of size 5213, which is longer than the specified 1000
# Created a chunk of size 5274, which is longer than the specified 1000
# Created a chunk of size 5279, which is longer than the specified 1000
# Created a chunk of size 5242, which is longer than the specified 1000
# Created a chunk of size 5322, which is longer than the specified 1000
# Created a chunk of size 5179, which is longer than the specified 1000
# Created a chunk of size 5166, which is longer than the specified 1000
# Created a chunk of size 5024, which is longer than the specified 1000
# Created a chunk of size 5157, which is longer than the specified 1000
# Created a chunk of size 5049, which is longer than the specified 1000
# Created a chunk of size 5700, which is longer than the specified 1000
# Created a chunk of size 1083, which is longer than the specified 1000
# Created a chunk of size 1228, which is longer than the specified 1000
# Created a chunk of size 6291, which is longer than the specified 1000
# Created a chunk of size 1305, which is longer than the specified 1000
# Created a chunk of size 6592, which is longer than the specified 1000
# Created a chunk of size 1621, which is longer than the specified 1000
# Created a chunk of size 5176, which is longer than the specified 1000
# Created a chunk of size 4992, which is longer than the specified 1000
# Created a chunk of size 5039, which is longer than the specified 1000
# Created a chunk of size 5282, which is longer than the specified 1000
# Created a chunk of size 1186, which is longer than the specified 1000
# Created a chunk of size 5181, which is longer than the specified 1000
# Created a chunk of size 5084, which is longer than the specified 1000
# Created a chunk of size 5210, which is longer than the specified 1000
# Created a chunk of size 5177, which is longer than the specified 1000
# Created a chunk of size 5036, which is longer than the specified 1000
# Created a chunk of size 5235, which is longer than the specified 1000
# Created a chunk of size 5185, which is longer than the specified 1000
# Created a chunk of size 5120, which is longer than the specified 1000
# Created a chunk of size 5238, which is longer than the specified 1000
# Created a chunk of size 5106, which is longer than the specified 1000
# Created a chunk of size 5524, which is longer than the specified 1000
# Created a chunk of size 2461, which is longer than the specified 1000
# Created a chunk of size 2049, which is longer than the specified 1000
# Created a chunk of size 1860, which is longer than the specified 1000
# Created a chunk of size 1758, which is longer than the specified 1000
# Created a chunk of size 1383, which is longer than the specified 1000
# Created a chunk of size 1367, which is longer than the specified 1000
# Created a chunk of size 2136, which is longer than the specified 1000
# Created a chunk of size 1323, which is longer than the specified 1000
# Created a chunk of size 1358, which is longer than the specified 1000
# Created a chunk of size 5051, which is longer than the specified 1000
# Created a chunk of size 4904, which is longer than the specified 1000
# Created a chunk of size 4908, which is longer than the specified 1000
# Created a chunk of size 4904, which is longer than the specified 1000
# Created a chunk of size 4896, which is longer than the specified 1000
# Created a chunk of size 4938, which is longer than the specified 1000
# Created a chunk of size 4906, which is longer than the specified 1000
# Created a chunk of size 4902, which is longer than the specified 1000
# Created a chunk of size 4938, which is longer than the specified 1000
# Created a chunk of size 5022, which is longer than the specified 1000
# Created a chunk of size 5347, which is longer than the specified 1000
# Created a chunk of size 5087, which is longer than the specified 1000
# Created a chunk of size 5000, which is longer than the specified 1000
# Created a chunk of size 5084, which is longer than the specified 1000
# Created a chunk of size 5174, which is longer than the specified 1000
# Created a chunk of size 5094, which is longer than the specified 1000
# Created a chunk of size 5111, which is longer than the specified 1000
# Created a chunk of size 5134, which is longer than the specified 1000
# Created a chunk of size 5083, which is longer than the specified 1000
# Created a chunk of size 5262, which is longer than the specified 1000
# Created a chunk of size 5106, which is longer than the specified 1000
# Created a chunk of size 5254, which is longer than the specified 1000
# Created a chunk of size 5335, which is longer than the specified 1000
# Created a chunk of size 5013, which is longer than the specified 1000
# Created a chunk of size 5116, which is longer than the specified 1000
# Created a chunk of size 5076, which is longer than the specified 1000
# Created a chunk of size 5308, which is longer than the specified 1000
# Created a chunk of size 4977, which is longer than the specified 1000
# Created a chunk of size 5118, which is longer than the specified 1000
# Created a chunk of size 5153, which is longer than the specified 1000
# Created a chunk of size 5646, which is longer than the specified 1000
# Created a chunk of size 5019, which is longer than the specified 1000
# Created a chunk of size 5198, which is longer than the specified 1000
# Created a chunk of size 5572, which is longer than the specified 1000
# Created a chunk of size 5885, which is longer than the specified 1000
# Created a chunk of size 5756, which is longer than the specified 1000
# Created a chunk of size 5127, which is longer than the specified 1000
# Created a chunk of size 5128, which is longer than the specified 1000
# Created a chunk of size 5090, which is longer than the specified 1000
# Created a chunk of size 5247, which is longer than the specified 1000
# Created a chunk of size 5133, which is longer than the specified 1000
# Created a chunk of size 5263, which is longer than the specified 1000
# Created a chunk of size 5058, which is longer than the specified 1000
# Created a chunk of size 5027, which is longer than the specified 1000
# Created a chunk of size 5073, which is longer than the specified 1000
# Created a chunk of size 1189, which is longer than the specified 1000
# Created a chunk of size 5088, which is longer than the specified 1000
# Created a chunk of size 5747, which is longer than the specified 1000
# Created a chunk of size 5075, which is longer than the specified 1000
# Created a chunk of size 5394, which is longer than the specified 1000
# Created a chunk of size 5028, which is longer than the specified 1000
# Created a chunk of size 5245, which is longer than the specified 1000
# Created a chunk of size 5220, which is longer than the specified 1000
# Created a chunk of size 5235, which is longer than the specified 1000
# Created a chunk of size 4956, which is longer than the specified 1000
# Created a chunk of size 5340, which is longer than the specified 1000
# Created a chunk of size 5070, which is longer than the specified 1000
# Created a chunk of size 5271, which is longer than the specified 1000
# Created a chunk of size 5060, which is longer than the specified 1000
# Created a chunk of size 5026, which is longer than the specified 1000
# Created a chunk of size 5035, which is longer than the specified 1000
# Created a chunk of size 5032, which is longer than the specified 1000
# Created a chunk of size 5065, which is longer than the specified 1000
# Created a chunk of size 5409, which is longer than the specified 1000
# Created a chunk of size 5362, which is longer than the specified 1000
# Created a chunk of size 5543, which is longer than the specified 1000
# Created a chunk of size 1323, which is longer than the specified 1000
# Created a chunk of size 5206, which is longer than the specified 1000
# Created a chunk of size 5701, which is longer than the specified 1000
# Created a chunk of size 5276, which is longer than the specified 1000
# Created a chunk of size 5103, which is longer than the specified 1000
# Created a chunk of size 5037, which is longer than the specified 1000
# Created a chunk of size 5506, which is longer than the specified 1000
# Created a chunk of size 5449, which is longer than the specified 1000
# Created a chunk of size 5015, which is longer than the specified 1000
# Created a chunk of size 5196, which is longer than the specified 1000
# Created a chunk of size 5075, which is longer than the specified 1000
# Created a chunk of size 5039, which is longer than the specified 1000
# Created a chunk of size 5115, which is longer than the specified 1000
# Created a chunk of size 5212, which is longer than the specified 1000
# Created a chunk of size 5040, which is longer than the specified 1000
# Created a chunk of size 5060, which is longer than the specified 1000
# Created a chunk of size 5140, which is longer than the specified 1000
# Created a chunk of size 5733, which is longer than the specified 1000
# Created a chunk of size 5648, which is longer than the specified 1000
# Created a chunk of size 5534, which is longer than the specified 1000
# Created a chunk of size 5165, which is longer than the specified 1000
# Created a chunk of size 1423, which is longer than the specified 1000
# Created a chunk of size 2598, which is longer than the specified 1000
# Created a chunk of size 1546, which is longer than the specified 1000
# Created a chunk of size 1243, which is longer than the specified 1000
# Created a chunk of size 1765, which is longer than the specified 1000
# Created a chunk of size 1635, which is longer than the specified 1000
# Created a chunk of size 1870, which is longer than the specified 1000
# Created a chunk of size 1690, which is longer than the specified 1000
# Created a chunk of size 1773, which is longer than the specified 1000
# Created a chunk of size 2019, which is longer than the specified 1000
# Created a chunk of size 1721, which is longer than the specified 1000
# Created a chunk of size 1892, which is longer than the specified 1000
# Created a chunk of size 1789, which is longer than the specified 1000
# Created a chunk of size 1720, which is longer than the specified 1000
# Created a chunk of size 1724, which is longer than the specified 1000
# Created a chunk of size 4992, which is longer than the specified 1000
# Created a chunk of size 4992, which is longer than the specified 1000
# Created a chunk of size 4992, which is longer than the specified 1000
# Created a chunk of size 4992, which is longer than the specified 1000
# Created a chunk of size 4992, which is longer than the specified 1000
# Created a chunk of size 1596, which is longer than the specified 1000
# Created a chunk of size 1676, which is longer than the specified 1000
# Created a chunk of size 1653, which is longer than the specified 1000
# Created a chunk of size 1758, which is longer than the specified 1000
# Created a chunk of size 1812, which is longer than the specified 1000
# Created a chunk of size 1955, which is longer than the specified 1000
# Created a chunk of size 1635, which is longer than the specified 1000
# Created a chunk of size 2140, which is longer than the specified 1000
# Created a chunk of size 1868, which is longer than the specified 1000
# Created a chunk of size 1734, which is longer than the specified 1000
# Created a chunk of size 2096, which is longer than the specified 1000
# Created a chunk of size 1804, which is longer than the specified 1000
# Created a chunk of size 1806, which is longer than the specified 1000
# Created a chunk of size 1870, which is longer than the specified 1000
# Created a chunk of size 1708, which is longer than the specified 1000
# Created a chunk of size 1754, which is longer than the specified 1000
# Created a chunk of size 1707, which is longer than the specified 1000
# Created a chunk of size 1698, which is longer than the specified 1000
# Created a chunk of size 1704, which is longer than the specified 1000
# Created a chunk of size 1698, which is longer than the specified 1000
# Created a chunk of size 1635, which is longer than the specified 1000
# Created a chunk of size 2090, which is longer than the specified 1000
# Created a chunk of size 2129, which is longer than the specified 1000
# Created a chunk of size 1956, which is longer than the specified 1000
# Created a chunk of size 1779, which is longer than the specified 1000
# Created a chunk of size 1679, which is longer than the specified 1000
# Created a chunk of size 1708, which is longer than the specified 1000
# Created a chunk of size 1785, which is longer than the specified 1000
# Created a chunk of size 1695, which is longer than the specified 1000
# Created a chunk of size 1701, which is longer than the specified 1000
# Created a chunk of size 1752, which is longer than the specified 1000
# Created a chunk of size 1809, which is longer than the specified 1000
# Created a chunk of size 1758, which is longer than the specified 1000
# Created a chunk of size 1684, which is longer than the specified 1000
# Created a chunk of size 1671, which is longer than the specified 1000
# Created a chunk of size 1656, which is longer than the specified 1000
# Created a chunk of size 1918, which is longer than the specified 1000
# Created a chunk of size 1751, which is longer than the specified 1000
# Created a chunk of size 1707, which is longer than the specified 1000
# Created a chunk of size 1789, which is longer than the specified 1000
# Created a chunk of size 1829, which is longer than the specified 1000
# Created a chunk of size 1816, which is longer than the specified 1000
# Created a chunk of size 1704, which is longer than the specified 1000
# Created a chunk of size 1815, which is longer than the specified 1000
# Created a chunk of size 1718, which is longer than the specified 1000
# Created a chunk of size 1717, which is longer than the specified 1000
# Created a chunk of size 1738, which is longer than the specified 1000
# Created a chunk of size 1692, which is longer than the specified 1000
# Created a chunk of size 1700, which is longer than the specified 1000
# Created a chunk of size 1712, which is longer than the specified 1000
# Created a chunk of size 1879, which is longer than the specified 1000
# Created a chunk of size 1879, which is longer than the specified 1000
# Created a chunk of size 1876, which is longer than the specified 1000
# Created a chunk of size 1702, which is longer than the specified 1000
# Created a chunk of size 1715, which is longer than the specified 1000
# Created a chunk of size 1950, which is longer than the specified 1000
# Created a chunk of size 1706, which is longer than the specified 1000
# Created a chunk of size 1777, which is longer than the specified 1000
# Created a chunk of size 1827, which is longer than the specified 1000
# Created a chunk of size 1509, which is longer than the specified 1000
# Created a chunk of size 1778, which is longer than the specified 1000
# Created a chunk of size 2678, which is longer than the specified 1000
# Created a chunk of size 1514, which is longer than the specified 1000
# Created a chunk of size 5495, which is longer than the specified 1000
# Created a chunk of size 4879, which is longer than the specified 1000
# Created a chunk of size 1514, which is longer than the specified 1000
# Created a chunk of size 5049, which is longer than the specified 1000
# Created a chunk of size 30692, which is longer than the specified 1000
# Created a chunk of size 4992, which is longer than the specified 1000
# Created a chunk of size 4992, which is longer than the specified 1000
# /tmp/ipykernel_54932/2852875601.py:75: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings()
# /tmp/ipykernel_54932/2852875601.py:75: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   embeddings = HuggingFaceEmbeddings()
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.local/lib/python3.9/site-packages/langchain_community/embeddings/huggingface.py:84, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      83 try:
# ---> 84     import sentence_transformers
#      86 except ImportError as exc:
#
# ModuleNotFoundError: No module named 'sentence_transformers'
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 75
#      72 split_docs = text_splitter.split_documents(documents)
#      74 # Initialize embeddings using a HuggingFace model and build a FAISS vector store.
# ---> 75 embeddings = HuggingFaceEmbeddings()
#      76 vectorstore = FAISS.from_documents(split_docs, embeddings)
#      78 print("Vectorstore created.")
#
# File ~/.local/lib/python3.9/site-packages/langchain_core/_api/deprecation.py:214, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     212     warned = True
#     213     emit_warning()
# --> 214 return wrapped(self, *args, **kwargs)
#
# File ~/.local/lib/python3.9/site-packages/langchain_community/embeddings/huggingface.py:87, in HuggingFaceEmbeddings.__init__(self, **kwargs)
#      84     import sentence_transformers
#      86 except ImportError as exc:
# ---> 87     raise ImportError(
#      88         "Could not import sentence_transformers python package. "
#      89         "Please install it with `pip install sentence-transformers`."
#      90     ) from exc
#      92 self.client = sentence_transformers.SentenceTransformer(
#      93     self.model_name, cache_folder=self.cache_folder, **self.model_kwargs
#      94 )
#
# ImportError: Could not import sentence_transformers python package. Please install it with `pip install sentence-transformers`.
